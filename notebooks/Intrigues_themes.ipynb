# %% [markdown]
# # Bibliographic data: Intrigues et thèmes
#
# Source of data: Martin, Angus, Vivienne Mylne, und Richard L. Frautschi. Bibliographie du genre romanesque français, 1751-1800, Introduction.  London: Mansell, 1977

# %%
pip install pygal  #Installing pygal
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#Installing'

# %% [markdown]
# To display the chart within the Jupyter Notebook:

# %%
from IPython.display import display, HTML

base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %% [markdown]
# # Intrigues et thèmes
# We import `pandas` and `pygal` and read in the csv-File. Printing out the table to check if it is ok:

# %%
import pandas as pd
import pygal
df = pd.read_csv("intrigues_themes.csv", sep=';')    
df
# Out:
#     year   a   b  c   d   e   f  g  h  i   j  k  l   m   n
# 0   1751   8   9  1   8   4   4  2  0  1   4  2  3   1   3
# 1   1752   9   4  4   6   3   7  2  1  0   4  4  2   1   1
# 2   1753   9   4  0   5   3   0  0  0  0   7  5  0   1   4
# 3   1754   7   9  1   6   7   4  4  3  0   4  1  0   1   4
# 4   1755   9  10  1   6   5  10  3  1  0   3  2  2   0   5
# 5   1756  10   6  0   3   0   5  1  1  0   4  1  3   1   2
# 6   1757   5   3  0   1   0   2  1  0  0   0  1  1   1   4
# 7   1758   6   0  0   0   0   2  1  1  0   1  4  2   0   3
# 8   1759   3   0  0   4   0   4  0  1  0   2  1  3   2   1
# 9   1760   4   1  2   9   0   6  0  0  0   2  0  4   1   1
# 10  1761   3   3  1   3   2   4  0  0  0   2  1  2   1   5
# 11  1762   7   7  2   5   2   8  1  0  0   0  0  0   0   7
# 12  1763   8   8  1  10   6   6  0  0  1   1  0  5   0   6
# 13  1764  14   2  0  10   4   2  0  1  0   0  0  0   1   6
# 14  1765  15   8  0   7   5   6  2  2  0   2  1  4   2   6
# 15  1766  17   3  0   6   4   5  2  2  0   2  1  2   1   9
# 16  1767  24   5  0  14   6   8  0  1  0   3  1  6   3   7
# 17  1768  15   9  0  19   5  11  1  2  0   4  0  6   1   3
# 18  1769  26   7  0  12   4  16  2  2  0   2  1  1   3   7
# 19  1770  26   8  2  17  11  10  2  6  0   4  2  3   0   7
# 20  1771  13   2  1  12   5   5  1  1  0   1  0  4   2   4
# 21  1772  17   3  1   6   4   6  1  1  1   2  1  3   1   2
# 22  1773  12   5  0   7   5   6  2  5  0   2  3  1   1   4
# 23  1774   9   4  0   2   1   3  2  2  1   2  0  2   0   3
# 24  1775  17   5  0   4   2   7  3  2  1   3  1  2   0   4
# 25  1776  17   3  0   8   3   6  0  5  0   3  0  1   1   3
# 26  1777  19   4  2  10   4  13  2  3  0   0  2  1   1   5
# 27  1778  12   4  0   3   4   8  2  0  0   1  0  1   2   4
# 28  1779  14   5  0   5   6   8  1  4  1   1  0  2   1   2
# 29  1780  16   1  0   4   2   3  0  3  4   2  0  2   2   2
# 30  1781   6   4  0   4   1   5  3  1  0   1  2  2   0   3
# 31  1782   9   5  0   5   2   3  4  2  0   1  2  3   3   1
# 32  1783  18   9  4   6  10   6  4  6  5   2  1  2   3   7
# 33  1784  13   8  2  11  10   6  4  0  0   3  3  2   4   4
# 34  1785  16   5  2   5  10   8  2  3  0   3  3  1   2   2
# 35  1786  20   5  2  12   8   4  4  3  0   1  2  1   3   5
# 36  1787  18   9  2  20   9  14  2  2  0   1  0  4   6   4
# 37  1788  47  12  2  18  19  18  5  1  1   2  0  3   4   5
# 38  1789  40   5  3  16  24  21  9  7  2   7  5  7   8   8
# 39  1790  15   4  3   9   9  11  4  1  1   3  2  4   3   2
# 40  1791   7   2  2   7   8   4  3  2  0   0  2  3   2   1
# 41  1792   9   5  5   8   4   6  4  1  1   0  1  1   1   0
# 42  1793   7   2  3   2   2   0  0  1  0   0  1  1   0   2
# 43  1794   8   1  0   3   2   2  0  0  0   0  0  1   1   0
# 44  1795  13   3  1  10   8   4  2  1  1   1  1  2   7   1
# 45  1796  23   6  1  11   5  12  1  1  1   3  1  3   3   4
# 46  1797  29   7  1  28   9  12  0  5  1   2  0  4   6   4
# 47  1798  31   9  2  41  14  17  2  4  0   3  0  5   5   8
# 48  1799  56  20  3  60  19  28  4  7  2  12  0  5  13  17
# 49  1800  55   7  6  51  17  15  5  8  3   1  2  4   3   9

# %%
import pygal
from pygal.style import Style


custom_style = Style(
    font_family='Roboto,Helvetica,Arial,sans-serif',
    label_font_size=12,
)
c = pygal.Bar(style=custom_style, y_title='Thèmes',
    width=1900,
    x_label_rotation=270,)
#c.add('Intrigues sentimentales', df['a'])
#c.add('Intrigues galantes', df['b'])
#c.add('Episodes pornographiques', df['c'])
#c.add('Aventures romanesques', df['d'])
c.add('Voyages', df['e'])
#c.add('Romans d`éducation', df['m'])
c.x_labels = df['year']



c.render_to_file('themes.svg')
display(HTML(base_html.format(rendered_chart=c.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-4f69547d-ab17-47a7-99b1-55eb383f45a1" class="pygal-chart" viewBox="0 0 1900 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Roboto,Helvetica,Arial,sans-serif}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .title{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:16px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .legends .legend text{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:14px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis text{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:12px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis text.major{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:10px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .text-overlay text.value{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:16px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .text-overlay text.label{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:10px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:14px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 text.no_data{font-family:Roboto,Helvetica,Arial,sans-serif;font-size:64px}
# #chart-4f69547d-ab17-47a7-99b1-55eb383f45a1{background-color:rgba(249,249,249,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 path,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 rect,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .graph{fill:rgba(0,0,0,.87)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 text.no_data{fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .title{fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .line{stroke:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis text.major{fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y .guides:hover .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .line-graph .axis.x .guides:hover .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .ci{stroke:rgba(0,0,0,.87)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .reactive.active,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .ci .reactive.active{stroke-width:1.5}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .series text{fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip .value{font-size:1.5em}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .bound{font-size:.5em}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .color-0,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .text-overlay .color-0 text{fill:black}
# #chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 text.no_data{text-anchor:middle}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .guide.line{fill:none}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .centered{text-anchor:middle}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .title{text-anchor:middle}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .legends .legend text{fill-opacity:1}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.x text{text-anchor:middle}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y text{text-anchor:end}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y text[transform].backwards{text-anchor:start}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y2 text{text-anchor:start}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y2 text[transform].backwards{text-anchor:end}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .guide.line{stroke-dasharray:4,4}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .major.guide.line{stroke-dasharray:6,6}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .horizontal .axis.y .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .horizontal .axis.y2 .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .vertical .axis.x .guide.line{opacity:0}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .horizontal .axis.always_show .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y .guides:hover .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.y2 .guides:hover .guide.line,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis.x .guides:hover .guide.line{opacity:1}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .axis .guides:hover text{opacity:1}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .nofill{fill:none}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .subtle-fill{fill-opacity:.2}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .dot{stroke-width:1px;fill-opacity:1}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .dot.active{stroke-width:5px}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .dot.negative{fill:transparent}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 text,#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 tspan{stroke:none !important}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .series text.active{opacity:1}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip rect{fill-opacity:.95;stroke-width:.5}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .tooltip text{fill-opacity:1}#chart-4f69547d-ab17-47a7-99b1-55eb383f45a1 .show

# %%
import pygal                                                       # First import pygal
bar_chart = pygal.Bar()                                            # Then create a bar graph object

bar_chart.add ('1752', [9, 4, 4, 6, 3 ,7 ,2 ,1, 0, 4, 4, 2, 1 , 1])# Add some values   	1752 
bar_chart.add('1796', [23, 6, 1, 11, 5, 12, 1, 1, 1, 3, 1, 3, 3, 4]) # Add some values
#bar_char.add(raw["a"])
bar_chart.title = 'Intrigues et thèmes' #add the Bar chart title
bar_chart.x_labels = 'a) Intrigues sentimentales et amours pastorales', 'b) Intrigues galantes et libertines.', 'c) Episodes scabreux, pornographiques', 'd) Aventures romanesques, mystères, etc.','e) Voyages', 'f) Peinture et critique des mœurs', 'g) Intrigues politiques et de cour; guerres', 'h) Eléments historiques et pseudo-historiques','i) Chevalerie, genre troubadour', 'j) Contes des fées, éléments merveilleux, légende, Bible', 'k) Allégorie', 'l) Thèmes et idées philosophiques, utopie', 'm) Ouvrages didactiques et pédagogiques, romans d`éducation', 'n) Intentions moralisatrices, histoires édifiantes, enseignement religieux'
#' #adding the x labels 
bar_chart.render_to_file('intrigues_et_themes.svg') # Save the svg to a file
display(HTML(base_html.format(rendered_chart=bar_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-06-30--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7{background-color:rgba(249,249,249,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 path,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 rect,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .graph{fill:rgba(0,0,0,.87)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 text.no_data{fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .title{fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .line{stroke:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis text.major{fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y .guides:hover .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .line-graph .axis.x .guides:hover .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .ci{stroke:rgba(0,0,0,.87)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .reactive.active,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .ci .reactive.active{stroke-width:1.5}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .series text{fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .tooltip .value{font-size:1.5em}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .bound{font-size:.5em}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .color-0,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .color-1,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .text-overlay .color-0 text{fill:black}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .text-overlay .color-1 text{fill:black}
# #chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 text.no_data{text-anchor:middle}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .guide.line{fill:none}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .centered{text-anchor:middle}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .title{text-anchor:middle}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .legends .legend text{fill-opacity:1}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.x text{text-anchor:middle}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y text{text-anchor:end}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y text[transform].backwards{text-anchor:start}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y2 text{text-anchor:start}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y2 text[transform].backwards{text-anchor:end}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .guide.line{stroke-dasharray:4,4}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .major.guide.line{stroke-dasharray:6,6}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .horizontal .axis.y .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .horizontal .axis.y2 .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .vertical .axis.x .guide.line{opacity:0}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .horizontal .axis.always_show .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y .guides:hover .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.y2 .guides:hover .guide.line,#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis.x .guides:hover .guide.line{opacity:1}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .axis .guides:hover text{opacity:1}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .nofill{fill:none}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .subtle-fill{fill-opacity:.2}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .dot{stroke-width:1px;fill-opacity:1}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .dot.active{stroke-width:5px}#chart-5d62dbfa-5c39-4ff2-b6ae-9d081d6f43f7 .dot.negative{fill:transparent}#chart-5d62dbfa-5c39-4ff2-b6ae

# %%
import pygal                                                       # First import pygal
bar_chart = pygal.Bar()                                            # Then create a bar graph object

bar_chart.add ('voyage', [1772, 
1778,
1783,
1762,
1788,
1787,
1761,
1798,
1795,
1759,
1768
])# Add some values   	1752 
#bar_chart.add('1796', [23, 6, 1, 11, 5, 12, 1, 1, 1, 3, 1, 3, 3, 4]) # Add some values
#bar_char.add(raw["a"])
bar_chart.title = 'Voyage' #add the Bar chart title
bar_chart.x_labels = 'Le Diable amoureux', 'Jacques le fataliste et son maître', 'Galatée', 'La vie et les aventures de Joseph Thompson', 'Collection de romans et contes', 'Une année dans la vie du chevalier de Faublas', 'Daïra. Histoire orientale', 'Pauliska ou la Perversité moderne', 'Aline et Valcour ou le roman philosophique', 
'Candide', 'La Princesse de Babylone'
#' #adding the x labels 
bar_chart.render_to_file('intrigues_et_themes.svg') # Save the svg to a file
display(HTML(base_html.format(rendered_chart=bar_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-23f5edfa-146d-4252-b655-59892fe5e584" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.4.0 (lxml) ©Kozea 2012-2016 on 2021-07-01--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-23f5edfa-146d-4252-b655-59892fe5e584{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-23f5edfa-146d-4252-b655-59892fe5e584{background-color:rgba(249,249,249,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 path,#chart-23f5edfa-146d-4252-b655-59892fe5e584 line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 rect,#chart-23f5edfa-146d-4252-b655-59892fe5e584 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .graph{fill:rgba(0,0,0,.87)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 text.no_data{fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .title{fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .line{stroke:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis text.major{fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y .guides:hover .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .line-graph .axis.x .guides:hover .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .ci{stroke:rgba(0,0,0,.87)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .reactive.active,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .ci .reactive.active{stroke-width:1.5}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .series text{fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip .value{font-size:1.5em}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .bound{font-size:.5em}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .color-0,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .text-overlay .color-0 text{fill:black}
# #chart-23f5edfa-146d-4252-b655-59892fe5e584 text.no_data{text-anchor:middle}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .guide.line{fill:none}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .centered{text-anchor:middle}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .title{text-anchor:middle}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .legends .legend text{fill-opacity:1}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.x text{text-anchor:middle}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y text{text-anchor:end}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y text[transform].backwards{text-anchor:start}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y2 text{text-anchor:start}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y2 text[transform].backwards{text-anchor:end}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .guide.line{stroke-dasharray:4,4}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .major.guide.line{stroke-dasharray:6,6}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .horizontal .axis.y .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .horizontal .axis.y2 .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .vertical .axis.x .guide.line{opacity:0}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .horizontal .axis.always_show .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y .guides:hover .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.y2 .guides:hover .guide.line,#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis.x .guides:hover .guide.line{opacity:1}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .axis .guides:hover text{opacity:1}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .nofill{fill:none}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .subtle-fill{fill-opacity:.2}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .dot{stroke-width:1px;fill-opacity:1}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .dot.active{stroke-width:5px}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .dot.negative{fill:transparent}#chart-23f5edfa-146d-4252-b655-59892fe5e584 text,#chart-23f5edfa-146d-4252-b655-59892fe5e584 tspan{stroke:none !important}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .series text.active{opacity:1}#chart-23f5edfa-146d-4252-b655-59892fe5e584 .tooltip rect{fil

# %% [markdown]
# References
#
# * https://feststelltaste.github.io/software-analytics/notebooks/vis/experimental/pandas-pygal/effective_charting.html
# * http://www.pygal.org/en/stable/documentation/first_steps.html
# * https://programmer.ink/think/python-data-visualization-pygal-svg-csv-bar-line.html
# * https://opensource.com/article/20/6/pygal-python
